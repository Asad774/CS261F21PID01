# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
#install chrom webdriver
#webdriver can be downloaded from 
#https://chromedriver.storage.googleapis.com/index.html?path=94.0.4606.41/

names1=[]
Price=[]
ratin=[]
def getUrl(link):
    
    driver = webdriver.Chrome(executable_path=r"C:\Users\umara\Downloads\chromedriver_win32 (2)\chromedriver.exe")

    
    driver.get(link)
    data= driver.page_source
    soup = BeautifulSoup(data)

    for i in soup.find_all('div',{'class':'c3KeDq'}):
        names=[]
        Rupees=[]
        Rating=[]
        name = i.find('div',{'class':'c16H9d'})
        if name==None:
            print('Name = No Name')
        else:
            nam=name.get_text()
            names.append(nam)
            print(nam)
    
        price = i.find('div',{'class':'c3gUW0'})
        if price == None:
            print('price = No price')
        else:
            price = price.find('span',{'class':'c13VH6'})
            prin=price.get_text()
            Rupees.append(prin)
            print(prin)
            
        rated = i.find('div',{'class':'c2JB4x c6Ntq9'})
        if rated==None:
            rate=0
            Rating.append(rate)
            print("--------------------")
        else:
            rate=rated.get_text()
            Rating.append(rate)
            print("people Rated"+rate)
            print('----------------------')  
            
        names1.append(names)
        Price.append(Rupees)
        ratin.append(Rating)
        
    
      
        
        

getUrl("https://www.daraz.pk/smartphones/samsung/")
getUrl("https://www.daraz.pk/smartphones/infinix/")
getUrl("https://www.daraz.pk/smartphones/oppo/")
getUrl("https://www.daraz.pk/smartphones/realme/")
getUrl("https://www.daraz.pk/smartphones/nokia/")
getUrl("https://www.daraz.pk/smartphones/mi/?")
getUrl("https://www.daraz.pk/smartphones/tecno/")
getUrl("https://www.daraz.pk/smartphones/itel/")
getUrl("https://www.daraz.pk/smartphones/apple/")
getUrl("https://www.daraz.pk/smartphones/vivo/")
getUrl("https://www.daraz.pk/smartphones/huawei/")
getUrl("https://www.daraz.pk/smartphones/oneplus/")
getUrl("https://www.daraz.pk/smartphones/qmobile/")
getUrl("https://www.daraz.pk/smartphones/redmi/")
getUrl("https://www.daraz.pk/smartphones/sony/")
getUrl("https://www.daraz.pk/smartphones/memobile-123836282/")
getUrl("https://www.daraz.pk/smartphones/sharp/")
getUrl("https://www.daraz.pk/smartphones/mi/")
getUrl("https://www.daraz.pk/phones-tablets/?spm=a2a0e.searchlistcategory.breadcrumb.2.37b07b80uiO1li")
getUrl("https://www.daraz.pk/phones-tablets/lenuo/")
getUrl("https://www.daraz.pk/phones-tablets/vantime-123268868/")
getUrl("https://www.daraz.pk/phones-tablets/nillkin/")
getUrl("https://www.daraz.pk/phones-tablets/ordernation/")
getUrl("https://www.daraz.pk/phones-tablets/baseus/")
getUrl("https://www.daraz.pk/phones-tablets/nokia/")
getUrl("https://www.daraz.pk/phones-tablets/samsung/")
getUrl("https://www.daraz.pk/phones-tablets/youksh-281756/")
getUrl("https://www.daraz.pk/phones-tablets/rhinoshield/")
getUrl("https://www.daraz.pk/phones-tablets/itel/")
getUrl("https://www.daraz.pk/phones-tablets/xiaomi/")
getUrl("https://www.daraz.pk/phones-tablets/ugreen/")
getUrl("https://www.daraz.pk/phones-tablets/x-srg-123352680/")
getUrl("https://www.daraz.pk/phones-tablets/remax/")
getUrl("https://www.daraz.pk/phones-tablets/infinix/")
getUrl("https://www.daraz.pk/phones-tablets/zoop-265511/")
getUrl("https://www.daraz.pk/phones-tablets/huawei/")
getUrl("https://www.daraz.pk/phones-tablets/rayan-tech-284389/")
getUrl("https://www.daraz.pk/phones-tablets/tecno/")
getUrl("https://www.daraz.pk/phones-tablets/login/")
getUrl("https://www.daraz.pk/phones-tablets/vivo/")
getUrl("https://www.daraz.pk/phones-tablets/redmi/")
getUrl("https://www.daraz.pk/phones-tablets/mega-store/")
getUrl("https://www.daraz.pk/mobile-power-banks/?spm=a2a0e.searchlistcategory.card.7.1c3f38e3c16FRB&item_id=171444126&from=onesearch_category_2")
getUrl("https://www.daraz.pk/mobile-power-banks/romoss/?from=onesearch_category_2")
getUrl("https://www.daraz.pk/mobile-power-banks/xiaomi/")
getUrl("https://www.daraz.pk/mobile-power-banks/kp(king-kp&power-power-system)-123548700/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/?spm=a2a0e.searchlistcategory.breadcrumb.3.69884debFz22ss")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/mega-store/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/lenuo/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/lenuo/?page=2")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/topk/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/realme/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/zaw/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/vantime-123268868/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/alogy-123778621/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/snk-fitness-121143035/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/musino-123563436/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/friends-engineering-283010/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/datari-traders-123710236/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/baseus/")
getUrl("https://www.daraz.pk/mobiles-tablets-accessories/x-srg-123352680/")
getUrl("https://www.daraz.pk/laptops/?spm=a2a0e.home.cate_1.5.52894937V6ygDB")
getUrl("https://www.daraz.pk/laptops/hp/")
getUrl("https://www.daraz.pk/laptops/dell/")
getUrl("https://www.daraz.pk/laptops/lenovo/")
getUrl("https://www.daraz.pk/laptops/infinix/")
getUrl("https://www.daraz.pk/laptops/acer/")
getUrl("https://www.daraz.pk/laptops/samsung/")
getUrl("https://www.daraz.pk/laptops/apple/")
getUrl("https://www.daraz.pk/laptops/lenovo-thinkpad/")
getUrl("https://www.daraz.pk/laptops/asus/")
getUrl("https://www.daraz.pk/desktop-computer/?spm=a2a0e.home.cate_1.6.14894937iGOssj")
getUrl("https://www.daraz.pk/chromebooks/?spm=a2a0e.searchlistcategory.card.3.3141f3194HypFm&item_id=102010877&from=onesearch_category_55")
getUrl("https://www.daraz.pk/camera/?spm=a2a0e.home.cate_1.9.7e604937qo2YM2")
getUrl("https://www.daraz.pk/camera/canon/")
getUrl("https://www.daraz.pk/camera/nikon/")
getUrl("https://www.daraz.pk/camera/chromakey-123751411/")
getUrl("https://www.daraz.pk/camera/sony/")
getUrl("https://www.daraz.pk/camera/axle-123524674/")
getUrl("https://www.daraz.pk/camera/mango-tech-123416269/")
getUrl("https://www.daraz.pk/camera/lexar-media-123700618/")
getUrl("https://www.daraz.pk/camera/handboss/")
getUrl("https://www.daraz.pk/camera/sandisk-extreme-pro/")
getUrl("https://www.daraz.pk/headphones-headsets/?spm=a2a0e.home.cate_2.2.183749375qKu9N")
getUrl("https://www.daraz.pk/audio/?spm=a2a0e.searchlistcategory.breadcrumb.3.3cfd2b4etjrW5L")
getUrl("https://www.daraz.pk/audio/audionic/")
getUrl("https://www.daraz.pk/audio/klipsch/")
getUrl("https://www.daraz.pk/audio/misuli/")
getUrl("https://www.daraz.pk/audio/wiresto-123271809/")
getUrl("https://www.daraz.pk/audio/ugreen/")
getUrl("https://www.daraz.pk/audio/mega-store/")
getUrl("https://www.daraz.pk/audio/gionee/")
getUrl("https://www.daraz.pk/audio/sony/")
getUrl("https://www.daraz.pk/audio/logitech/")
getUrl("https://www.daraz.pk/audio/f-d/")
getUrl("https://www.daraz.pk/audio/lenovo/")
getUrl("https://www.daraz.pk/audio/audionic-pakistan-123237002/")
getUrl("https://www.daraz.pk/audio/akg/")
getUrl("https://www.daraz.pk/consumer-electronics/?spm=a2a0e.searchlistcategory.breadcrumb.2.64d26b53KpEDyp")
getUrl("https://www.daraz.pk/consumer-electronics/audionic/")
getUrl("https://www.daraz.pk/consumer-electronics/misuli/")
getUrl("https://www.daraz.pk/consumer-electronics/sony/")
getUrl("https://www.daraz.pk/consumer-electronics/gionee/")
getUrl("https://www.daraz.pk/consumer-electronics/lenovo/")
getUrl("https://www.daraz.pk/consumer-electronics/huayu/")
getUrl("https://www.daraz.pk/consumer-electronics/nintendo/")
getUrl("https://www.daraz.pk/consumer-electronics/xiaomi/")
getUrl("https://www.daraz.pk/consumer-electronics/boya/")
getUrl("https://www.daraz.pk/consumer-electronics/audionic-pakistan-123237002/")
getUrl("https://www.daraz.pk/consumer-electronics/iar-collections-266605/")
getUrl("https://www.daraz.pk/consumer-electronics/logitech/")
getUrl("https://www.daraz.pk/consumer-electronics/ugreen/")
getUrl("https://www.daraz.pk/consumer-electronics/cleanxo-123751899/")
getUrl("https://www.daraz.pk/consumer-electronics/wiresto-123271809/")
getUrl("https://www.daraz.pk/consumer-electronics/wiresto-123271809/")
getUrl("https://www.daraz.pk/consumer-electronics/accessories-walay-123953066/")
getUrl("https://www.daraz.pk/consumer-electronics/a4tech/")
getUrl("https://www.daraz.pk/consumer-electronics/microsoft/")
getUrl("https://www.daraz.pk/consumer-electronics/remax/")
getUrl("https://www.daraz.pk/consumer-electronics/ubisoft/")
getUrl("https://www.daraz.pk/consumer-electronics/gameranger-123971081/")
getUrl("https://www.daraz.pk/consumer-electronics/x-srg-123352680/")
getUrl("https://www.daraz.pk/consumer-electronics/capcom/")
getUrl("https://www.daraz.pk/consumer-electronics/fs-trades-123546277/")
getUrl("https://www.daraz.pk/consumer-electronics/tuker-123557064/")
#getUrl("")
#getUrl("")


df = pd.DataFrame({'Product Name':names1,'Price':Price,'Rating':ratin})
df.to_csv('electronics1.csv', index=False,encoding='utf-8')
# Out:
# Samsung Galaxy A32 - RAM 6GB - ROM 128 GB - Display 6.4 - Multi Quad Camera system -  Battery 5000 mAh 1 Year Official Warranty
# Rs. 42,999
# people Rated(99)
# ----------------------
# Samsung M31 - 6.4" Super AMOLED Display - 6GB RAM 128GB ROM - 64 MP Quad Camera - 6000 mAh Battery - PTA APPROVED
# Rs. 44,999
# people Rated(1088)
# ----------------------
# Samsung Galaxy A52s 5G 128GB | Display 6.5" | Back Camera 64+8+5+5MP | Selfi 32MP | RAM 8GB | Battery 4500 mAh
# Rs. 78,699
# --------------------
# Samsung Galaxy A01 - Display 5.7  - Dual Back Camera 13+2 MP - 5 MP Selfi Camera - 2GB RAM - 16 GB ROM
# Rs. 15,999
# people Rated(92)
# ----------------------
# Samsung Galaxy A72 - Display 6.7 - Quad Back Camera - 8GB RAM - 128GB ROM - Battery 5000 mAh
# Rs. 80,995
# --------------------
# Samsung Galaxy A12 6.5 Inch Display 4 GB RAM 128 GB ROM Dual Sim 1 Year Warranty
# Rs. 30,295
# people Rated(8)
# ----------------------
# ...
